# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR= "/content/gdrive/MyDrive/Project_main"

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 31.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 65.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 43.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.8 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO

model = YOLO("yolov8n.yaml")

results = model.train(data=os.path.join(ROOT_DIR, "data.yml"), epochs=400)
# Out:
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil

# Define the current location of the 'runs' directory
current_runs_dir = '/content/runs'

# Define the destination location where you want to move the 'runs' directory
destination_runs_dir = '/content/gdrive/MyDrive/Project_main'

# Move the 'runs' directory to the destination location
shutil.move(current_runs_dir, destination_runs_dir)

print("Runs directory moved to:", destination_runs_dir)
# Out:
# Runs directory moved to: /content/gdrive/MyDrive/Project_main

# %%
weights_path = "/content/runs/detect/train4/weights/best.pt"

with open(weights_path, "rb") as file:
    weights_data = file.read()

# Now weights_data contains the contents of the weights file

# %%
import os

directory = "/content/runs/detect/train4/weights/"
files = os.listdir(directory)
print(files)
# Out:
# ['best.pt', 'last.pt']

# %%
import os

from ultralytics import YOLO

model = YOLO("yolov8n.yaml")

# Define the path to the test folder
path = "/content/gdrive/MyDrive/Project_main/test"

# Modify the data argument to point to the test folder
results = model.train(data=os.path.join(ROOT_DIR, "data.yml"), epochs=50)
# Out:
# Ultralytics YOLOv8.1.36 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
